# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %%
import pandas as pd

# %%
df1 = pd.read_csv('supermarkets.csv')
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pd.read_json('supermarkets.json')
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pd.read_excel('supermarkets.xlsx', sheet_name=0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pd.read_csv('supermarkets-commas.txt')
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pd.read_csv('supermarkets-semi-colons.txt', sep =';')
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
pd.read_csv?

# %%
df5.set_index("ID")
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df6 = df5.set_index("Name")
df6
# Out:
#               ID          Address           City             State Country  \
# Name
# Madeira        1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop    2   735 Dolores St  San Francisco          CA 94119     USA
#  Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop     4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez        5  1056 Sanchez St  San Francisco        California     USA
# Richvalley     6  551 Alvarado St  San Francisco          CA 94114     USA
#
#               Employees
# Name
# Madeira               8
# Bready Shop          15
#  Super River         25
# Ben's Shop           10
# Sanchez              12
# Richvalley           20

# %%
df6.set_index("Address", inplace=True, drop=False)
df6
# Out:
#                          Address           City             State Country  \
# Address
# 3666 21st St        3666 21st St  San Francisco          CA 94114     USA
# 735 Dolores St    735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St          332 Hill St  San Francisco  California 94114     USA
# 3995 23rd St        3995 23rd St  San Francisco          CA 94114     USA
# 1056 Sanchez St  1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  551 Alvarado St  San Francisco          CA 94114     USA
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df6.loc["332 Hill St":"1056 Sanchez St", "Country":"Employees"]
# Out:
#                 Country  Employees
# Address
# 332 Hill St         USA         25
# 3995 23rd St        USA         10
# 1056 Sanchez St     USA         12

# %%
df6.iloc[2:5, 3:]
# Out:
#                 Country  Employees
# Address
# 332 Hill St         USA         25
# 3995 23rd St        USA         10
# 1056 Sanchez St     USA         12

# %%
df6.drop("Address", 1)
# Out:
#                           City             State Country  Employees
# Address
# 3666 21st St     San Francisco          CA 94114     USA          8
# 735 Dolores St   San Francisco          CA 94119     USA         15
# 332 Hill St      San Francisco  California 94114     USA         25
# 3995 23rd St     San Francisco          CA 94114     USA         10
# 1056 Sanchez St  San Francisco        California     USA         12
# 551 Alvarado St  San Francisco          CA 94114     USA         20

# %%
df6.drop(df6.index[0:3],0)
# Out:
#                          Address           City       State Country  Employees
# Address
# 3995 23rd St        3995 23rd St  San Francisco    CA 94114     USA         10
# 1056 Sanchez St  1056 Sanchez St  San Francisco  California     USA         12
# 551 Alvarado St  551 Alvarado St  San Francisco    CA 94114     USA         20

# %%
df6.drop(df6.columns[0:3], 1)
# Out:
#                 Country  Employees
# Address
# 3666 21st St        USA          8
# 735 Dolores St      USA         15
# 332 Hill St         USA         25
# 3995 23rd St        USA         10
# 1056 Sanchez St     USA         12
# 551 Alvarado St     USA         20

# %%
df6.shape
# Out:
# (6, 6)

# %%
df6['Continent'] = df6.shape[0]* ['North America']

# %%
df7 = df6.drop("Address",1)

# %%
df7_t = df7.T
df7_t
# Out:
# Address     3666 21st St 735 Dolores St       332 Hill St   3995 23rd St  \
# City       San Francisco  San Francisco     San Francisco  San Francisco
# State           CA 94114       CA 94119  California 94114       CA 94114
# Country              USA            USA               USA            USA
# Employees              8             15                25             10
# Continent  North America  North America     North America  North America
#
# Address   1056 Sanchez St 551 Alvarado St
# City        San Francisco   San Francisco
# State          California        CA 94114
# Country               USA             USA
# Employees              12              20
# Continent   North America   North America

# %%
df7_t['My Address'] = ['My City', 'My State', 'My Country', 'My Employees', 'My Continent']
df7_t
# Out:
# Address     3666 21st St 735 Dolores St       332 Hill St   3995 23rd St  \
# City       San Francisco  San Francisco     San Francisco  San Francisco
# State           CA 94114       CA 94119  California 94114       CA 94114
# Country              USA            USA               USA            USA
# Employees              8             15                25             10
# Continent  North America  North America     North America  North America
#
# Address   1056 Sanchez St 551 Alvarado St    My Address
# City        San Francisco   San Francisco       My City
# State          California        CA 94114      My State
# Country               USA             USA    My Country
# Employees              12              20  My Employees
# Continent   North America   North America  My Continent

# %%
df7 = df7_t.T
df7
# Out:
#                           City             State     Country     Employees  \
# Address
# 3666 21st St     San Francisco          CA 94114         USA             8
# 735 Dolores St   San Francisco          CA 94119         USA            15
# 332 Hill St      San Francisco  California 94114         USA            25
# 3995 23rd St     San Francisco          CA 94114         USA            10
# 1056 Sanchez St  San Francisco        California         USA            12
# 551 Alvarado St  San Francisco          CA 94114         USA            20
# My Address             My City          My State  My Country  My Employees
#
#                      Continent
# Address
# 3666 21st St     North America
# 735 Dolores St   North America
# 332 Hill St      North America
# 3995 23rd St     North America
# 1056 Sanchez St  North America
# 551 Alvarado St  North America
# My Address        My Continent

# %%
import geopy

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
#nom.geocode("1152 Kevin Drive, Columbus, IN 47201")
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# ...
